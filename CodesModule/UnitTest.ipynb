# %%
# # -*- coding: utf-8 -*-
# # 获取页面隐藏元素，网盘链接及密码
# 2017.11.15

# from selenium import webdriver
# from selenium.webdriver.support.select import Select
# import os,time
# import urllib

# def getUP(searchKey):
#     #searchKey = u'当你沉睡时'
#     url_main= 'http://m.mei123478.com/?s='
#     pre_url = url_main + urllib.quote_plus(searchKey.encode('utf8'))

#     # 第一部分：获取检索项进行重构url
#     driver_detail = webdriver.PhantomJS()
#     driver_detail.get(pre_url)
#     url = driver_detail.find_element_by_xpath("//div[@class='article']/h2/a").get_attribute('href')
#     #print url
#     driver_detail.get(url)

#     # 第二部分：将隐藏元素显现，设置display='block'
#     # thanks for :https://www.cnblogs.com/fnng/p/5365900.html
#     js = 'document.querySelectorAll("h2")[0].style.display="block";'
#     driver_detail.execute_script(js)
#     url_ = driver_detail.find_element_by_xpath("//div[@class='indent']/h2/span/a")
#     url = url_.get_attribute('href')

# 	# 第三部分：获取innerHTML元素，单使用.text的方法不能获取内容
# 	# 至于为什么不使用innerText: http://blog.csdn.net/magi1201/article/details/44131361
#     password_ = driver_detail.find_element_by_xpath("//div[@class='indent']/h2")
#     # thanks for：http://www.linuxhub.org/?p=3801
#     password =  password_.get_attribute("innerHTML").split("<")[-2][-4:]

# 	# 若使用innerText
#     # password2_ = password_.get_attribute("innerText")
#     # password2 = password2_.split(" ")[-1].strip()

#     driver_detail.quit()
#     return url, password

# if __name__ == '__main__':
#     url, password = getUP(u'今生是第一次')
#     print url, password
	

# -*- coding: utf-8 -*-
# 获取页面隐藏元素，网盘链接及密码
# 测试页面：http://m.mei123478.com/
# 页面描述：网盘链接和密码隐藏，所以第一步需要注入js进行显示，然后正常进行文本解析，因为字段比较简单，所以直接字符串解析了
# 注意：使用phantomjs等待时间比较久,所以调试是一个比较累人的工作
# 2017.11.17

from selenium import webdriver
from selenium.webdriver.support.select import Select
import os,time
import urllib

def getUP(searchKey):
    '''
    Input:searchKey '生活大爆炸'
    Return: {searchKey:[(link,password),]}
    
    '''
    url_main= 'http://m.mei123478.com/?s='
    pre_url = url_main + urllib.quote_plus(searchKey.encode('utf8'))

    # 第一部分：获取检索项进行重构url
    driver_detail = webdriver.PhantomJS()
    driver_detail.get(pre_url)
    url = driver_detail.find_element_by_xpath("//div[@class='article']/h2/a").get_attribute('href')
    driver_detail.get(url)

    # 第二部分：将隐藏元素显现，设置display='block'
    # thanks for :https://www.cnblogs.com/fnng/p/5365900.html
    # 注入js脚本，开启所有包含网盘内容的h2标签
    js = '''
    var urlpw = document.querySelectorAll("h2");
    var size_ = urlpw.length;
    for (i=0;i<size_;i++){urlpw[i].style.display='block'}
    '''
    driver_detail.execute_script(js)

    # 第三部分，解析隐藏字段，解析出网盘链接和密码
    #url_ = driver_detail.find_elements_by_xpath("//h2[@style='display: block;']")
    url_ = driver_detail.find_elements_by_xpath("//span[@style='color: #ff0000;']")  # 使用颜色属性，缩小范围
    urlpw = []    
    
    for hide in url_:
        innerHtml = hide.get_attribute("innerHTML")
        #print hide.text  # 度盘点我  密码: siua
        if 'http' in innerHtml:
            url = innerHtml.split("href=\"")[-1].split("\">")[0]
            #print url
            if u'密码' in innerHtml:
                pw = hide.text[-4:]
                #print pw
            else:
                #print 'No Password,just watch'
                pw = 'NoPW'
            urlpw.append((url,pw))

    driver_detail.quit()
    return {searchKey:urlpw}

if __name__ == '__main__':
    
#     test = [u'美国恐怖故事',u'当你沉睡时', u'无耻之徒', u'healer',u'生活大爆炸']
#     for i in test:
#         urlpw = getUP(i)
#         print urlpw
#         print '-----'
    urlpw = getUP(u'美国恐怖故事')
    print urlpw
# Out:
# {u'\u7f8e\u56fd\u6050\u6016\u6545\u4e8b': [(u'http://pan.baidu.com/s/1mhCJkes', u'i2jt'), (u'http://pan.baidu.com/s/1slhDEjj', u'zn49'), (u'https://pan.baidu.com/s/1jIL49MY', u'sxy3')]}

# %%
from selenium import webdriver
from selenium.webdriver.support.select import Select
import os,time
import urllib
url_main= 'http://m.mei123478.com/?s='
searchKey = u'jigsaw'
pre_url = url_main + urllib.quote_plus(searchKey.encode('utf8'))

# 第一部分：获取检索项进行重构url
driver_detail = webdriver.PhantomJS()
driver_detail.get(pre_url)
# url = driver_detail.find_element_by_xpath("//div[@class='article']/h2/a").get_attribute('href')

# print url

article_list = driver_detail.find_elements_by_xpath("//div[@class='article']/h2/a")

url_find = 'NoFound'
for article in article_list:
    if searchKey.encode('utf8') in article.text.encode('utf8'):
        url_find = article.get_attribute('href')
        break

print url_find   
driver_detail.quit()
#driver_detail.get(url)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-0dc1f6354a80> in <module>()
#       9 # 第一部分：获取检索项进行重构url
#      10 driver_detail = webdriver.PhantomJS()
# ---> 11 driver_detail.get(pre_url)
#      12 # url = driver_detail.find_element_by_xpath("//div[@class='article']/h2/a").get_attribute('href')
#      13
#
# /Users/mrlevo/anaconda/lib/python2.7/site-packages/selenium/webdriver/remote/webdriver.pyc in get(self, url)
#     266         Loads a web page in the current browser session.
#     267         """
# --> 268         self.execute(Command.GET, {'url': url})
#     269
#     270     @property
#
# /Users/mrlevo/anaconda/lib/python2.7/site-packages/selenium/webdriver/remote/webdriver.pyc in execute(self, driver_command, params)
#     252
#     253         params = self._wrap_value(params)
# --> 254         response = self.command_executor.execute(driver_command, params)
#     255         if response:
#     256             self.error_handler.check_response(response)
#
# /Users/mrlevo/anaconda/lib/python2.7/site-packages/selenium/webdriver/remote/remote_connection.pyc in execute(self, command, params)
#     462         path = string.Template(command_info[1]).substitute(params)
#     463         url = '%s%s' % (self._url, path)
# --> 464         return self._request(command_info[0], url, body=data)
#     465
#     466     def _request(self, method, url, body=None):
#
# /Users/mrlevo/anaconda/lib/python2.7/site-packages/selenium/webdriver/remote/remote_connection.pyc in _request(self, method, url, body)
#     524                 opener = url_request.build_opener(url_request.HTTPRedirectHandler(),
#     525                                                   HttpErrorHandler())
# --> 526             resp = opener.open(request, timeout=self._timeout)
#     527             statuscode = resp.code
#     528             if not hasattr(resp, 'getheader'):
#
# /Users/mrlevo/anaconda/lib/python2.7/urllib2.pyc in open(self, fullurl, data, timeout)
#     427             req = meth(req)
#     428
# --> 429         response = self._open(req, data)
#     430
#     431         # post-process response
#
# /Users/mrlevo/anaconda/lib/python2.7/urllib2.pyc in _open(self, req, data)
#     445         protocol = req.get_type()
#     446         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 447                                   '_open', req)
#     448         if result:
#     449             return result
#
# /Users/mrlevo/anaconda/lib/python2.7/urllib2.pyc in _call_chain(self, chain, kind, meth_name, *args)
#     405             func = getattr(handler, meth_name)
#     406
# --> 407             result = func(*args)
#     408             if result is not None:
#     409                 return result
#
# /Users/mrlevo/anaconda/lib/python2.7/urllib2.pyc in http_open(self, req)
#    1226
#    1227     def http_open(self, req):
# -> 1228         return self.do_open(httplib.HTTPConnection, req)
#    1229
#    1230     http_request = AbstractHTTPHandler.do_request_
#
# /Users/mrlevo/anaconda/lib/python2.7/urllib2.pyc in do_open(self, http_class, req, **http_conn_args)
#    1199         else:
#    1200             try:
# -> 1201                 r = h.getresponse(buffering=True)
#    1202             except TypeError: # buffering kw not supported
#    1203                 r = h.getresponse()
#
# /Users/mrlevo/anaconda/lib/python2.7/httplib.pyc in getresponse(self, buffering)
#    1119
#    1120         try:
# -> 1121             response.begin()
#    1122             assert response.will_close != _UNKNOWN
#    1123             self.__state = _CS_IDLE
#
# /Users/mrlevo/anaconda/lib/python2.7/httplib.pyc in begin(self)
#     436         # read until we get a non-100 response
#     437         while True:
# --> 438             version, status, reason = self._read_status()
#     439             if status != CONTINUE:
#     440                 break
#
# /Users/mrlevo/anaconda/lib/python2.7/httplib.pyc in _read_status(self)
#     392     def _read_status(self):
#     393         # Initialize with Simple-Response defaults
# --> 394         line = self.fp.readline(_MAXLINE + 1)
#     395         if len(line) > _MAXLINE:
#     396             raise LineTooLong("header line")
#
# /Users/mrlevo/anaconda/lib/python2.7/socket.pyc in readline(self, size)
#     478             while True:
#     479                 try:
# --> 480                     data = self._sock.recv(self._rbufsize)
#     481                 except error, e:
#     482                     if e.args[0] == EINTR:
#
# KeyboardInterrupt:

# %%
# -*- coding: utf-8 -*-
# 获取页面隐藏元素，网盘链接及密码
# 测试页面：http://m.mei123478.com/
# 页面描述：网盘链接和密码隐藏，所以第一步需要注入js进行显示，然后正常进行文本解析，因为字段比较简单，所以直接字符串解析了
# 注意：使用phantomjs等待时间比较久,所以调试是一个比较累人的工作
# 2017.11.20：修复多值检索项的匹配问题

from selenium import webdriver
from selenium.webdriver.support.select import Select
import os,time
import urllib

def getUP(searchKey):
    '''
    Input:searchKey u'生活大爆炸'
    Return: {searchKey:[(link,password),]}
    
    '''
    url_main= 'http://m.mei123478.com/?s='
    pre_url = url_main + urllib.quote_plus(searchKey.encode('utf8'))

    # 第一部分：获取检索项进行重构url
    driver_detail = webdriver.PhantomJS()
    driver_detail.get(pre_url)
    article_list = driver_detail.find_elements_by_xpath("//div[@class='article']/h2/a")
    url_find = 'NoFound'
    for article in article_list:
        if searchKey.encode('utf8') in article.text.encode('utf8'):
            url_find = article.get_attribute('href')
            break

#     print url_find 
    
    if url_find != 'NoFound':
        driver_detail.get(url_find)

        # 第二部分：将隐藏元素显现，设置display='block'
        # thanks for :https://www.cnblogs.com/fnng/p/5365900.html
        # 注入js脚本，开启所有包含网盘内容的h2标签
        js = '''
        var urlpw = document.querySelectorAll("h2");
        var size_ = urlpw.length;
        for (i=0;i<size_;i++){urlpw[i].style.display='block'}
        '''
        driver_detail.execute_script(js)

        # 第三部分，解析隐藏字段，解析出网盘链接和密码
        #url_ = driver_detail.find_elements_by_xpath("//h2[@style='display: block;']")
        url_ = driver_detail.find_elements_by_xpath("//span[@style='color: #ff0000;']")  # 使用颜色属性，缩小范围
        urlpw = []    

        for hide in url_:
            innerHtml = hide.get_attribute("innerHTML")
            #print hide.text  # 度盘点我  密码: siua
            if 'http' in innerHtml:
                url = innerHtml.split("href=\"")[-1].split("\">")[0]
                #print url
                if u'密码' in innerHtml:
                    pw = hide.text[-4:]
                    #print pw
                else:
                    #print 'No Password,just watch'
                    pw = 'NoPW'
                urlpw.append((url,pw))

        driver_detail.quit()
        return {searchKey:urlpw}
    else:
        return 'No Found or change the title try again!'

if __name__ == '__main__':
    
    test = [u'美国恐怖故事',u'当你沉睡时', u'无耻之徒', u'healer',u'生活大爆炸']
    for i in test:
        urlpw = getUP(i)
        print urlpw
        print '-----'
#     urlpw = getUP(u'美国恐怖故事')
#     print urlpw
# Out:
# http://m.mei123478.com/%e7%be%8e%e5%9b%bd%e6%81%90%e6%80%96%e6%95%85%e4%ba%8b1-6%e5%ad%a3-american-horror-storyseason-6-2016.html
# {u'\u7f8e\u56fd\u6050\u6016\u6545\u4e8b': [(u'http://pan.baidu.com/s/1mhCJkes', u'i2jt'), (u'http://pan.baidu.com/s/1slhDEjj', u'zn49'), (u'https://pan.baidu.com/s/1jIL49MY', u'sxy3')]}
# -----
# http://m.mei123478.com/%e5%bd%93%e4%bd%a0%e6%b2%89%e7%9d%a1%e6%97%b6-%eb%8b%b9%ec%8b%a0%ec%9d%b4-%ec%9e%a0%eb%93%a0-%ec%82%ac%ec%9d%b4%ec%97%90-2017.html
# {u'\u5f53\u4f60\u6c89\u7761\u65f6': [(u'https://pan.baidu.com/s/1c1Yrine', u'w5is')]}
# -----
# http://m.mei123478.com/%e6%97%a0%e8%80%bb%e4%b9%8b%e5%be%92%e7%be%8e%e7%89%88-1-7%e5%ad%a3-shameless-season-7-2016-2.html
# {u'\u65e0\u803b\u4e4b\u5f92': [(u'https://pan.baidu.com/s/1i5zk64t', u'6m43'), (u'https://pan.baidu.com/s/1kU7Et4V', u'hh7k')]}
# -----
# NoFound
# No Found or change the title try again!
# -----
# http://m.mei123478.com/%e7%94%9f%e6%b4%bb%e5%a4%a7%e7%88%86%e7%82%b8-the-big-bang-theory.html
# {u'\u751f\u6d3b\u5927\u7206\u70b8': [(u'https://pan.baidu.com/s/1qY8xYVi', u'zqtt'), (u'https://pan.baidu.com/s/1jIR7hye', u'kr2v'), (u'http://pan.baidu.com/s/1i4RdFWp', u'iua7')]}
# -----
