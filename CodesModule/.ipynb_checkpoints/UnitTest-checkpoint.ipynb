# %%
# # -*- coding: utf-8 -*-
# # 获取页面隐藏元素，网盘链接及密码
# 2017.11.15

# from selenium import webdriver
# from selenium.webdriver.support.select import Select
# import os,time
# import urllib

# def getUP(searchKey):
#     #searchKey = u'当你沉睡时'
#     url_main= 'http://m.mei123478.com/?s='
#     pre_url = url_main + urllib.quote_plus(searchKey.encode('utf8'))

#     # 第一部分：获取检索项进行重构url
#     driver_detail = webdriver.PhantomJS()
#     driver_detail.get(pre_url)
#     url = driver_detail.find_element_by_xpath("//div[@class='article']/h2/a").get_attribute('href')
#     #print url
#     driver_detail.get(url)

#     # 第二部分：将隐藏元素显现，设置display='block'
#     # thanks for :https://www.cnblogs.com/fnng/p/5365900.html
#     js = 'document.querySelectorAll("h2")[0].style.display="block";'
#     driver_detail.execute_script(js)
#     url_ = driver_detail.find_element_by_xpath("//div[@class='indent']/h2/span/a")
#     url = url_.get_attribute('href')

# 	# 第三部分：获取innerHTML元素，单使用.text的方法不能获取内容
# 	# 至于为什么不使用innerText: http://blog.csdn.net/magi1201/article/details/44131361
#     password_ = driver_detail.find_element_by_xpath("//div[@class='indent']/h2")
#     # thanks for：http://www.linuxhub.org/?p=3801
#     password =  password_.get_attribute("innerHTML").split("<")[-2][-4:]

# 	# 若使用innerText
#     # password2_ = password_.get_attribute("innerText")
#     # password2 = password2_.split(" ")[-1].strip()

#     driver_detail.quit()
#     return url, password

# if __name__ == '__main__':
#     url, password = getUP(u'今生是第一次')
#     print url, password
	

# -*- coding: utf-8 -*-
# 获取页面隐藏元素，网盘链接及密码
# 测试页面：http://m.mei123478.com/
# 页面描述：网盘链接和密码隐藏，所以第一步需要注入js进行显示，然后正常进行文本解析，因为字段比较简单，所以直接字符串解析了
# 注意：使用phantomjs等待时间比较久,所以调试是一个比较累人的工作
# 2017.11.17

from selenium import webdriver
from selenium.webdriver.support.select import Select
import os,time
import urllib

def getUP(searchKey):
    '''
    Input:searchKey '生活大爆炸'
    Return: {searchKey:[(link,password),]}
    
    '''
    url_main= 'http://m.mei123478.com/?s='
    pre_url = url_main + urllib.quote_plus(searchKey.encode('utf8'))

    # 第一部分：获取检索项进行重构url
    driver_detail = webdriver.PhantomJS()
    driver_detail.get(pre_url)
    url = driver_detail.find_element_by_xpath("//div[@class='article']/h2/a").get_attribute('href')
    driver_detail.get(url)

    # 第二部分：将隐藏元素显现，设置display='block'
    # thanks for :https://www.cnblogs.com/fnng/p/5365900.html
    # 注入js脚本，开启所有包含网盘内容的h2标签
    js = '''
    var urlpw = document.querySelectorAll("h2");
    var size_ = urlpw.length;
    for (i=0;i<size_;i++){urlpw[i].style.display='block'}
    '''
    driver_detail.execute_script(js)

    # 第三部分，解析隐藏字段，解析出网盘链接和密码
    #url_ = driver_detail.find_elements_by_xpath("//h2[@style='display: block;']")
    url_ = driver_detail.find_elements_by_xpath("//span[@style='color: #ff0000;']")  # 使用颜色属性，缩小范围
    urlpw = []    
    
    for hide in url_:
        innerHtml = hide.get_attribute("innerHTML")
        #print hide.text  # 度盘点我  密码: siua
        if 'http' in innerHtml:
            url = innerHtml.split("href=\"")[-1].split("\">")[0]
            #print url
            if u'密码' in innerHtml:
                pw = hide.text[-4:]
                #print pw
            else:
                #print 'No Password,just watch'
                pw = 'NoPW'
            urlpw.append((url,pw))

    driver_detail.quit()
    return {searchKey:urlpw}

if __name__ == '__main__':
    
#     test = [u'美国恐怖故事',u'当你沉睡时', u'无耻之徒', u'healer',u'生活大爆炸']
#     for i in test:
#         urlpw = getUP(i)
#         print urlpw
#         print '-----'
    urlpw = getUP(u'美国恐怖故事')
    print urlpw
# Out:
# {u'\u7f8e\u56fd\u6050\u6016\u6545\u4e8b': [(u'http://pan.baidu.com/s/1mhCJkes', u'i2jt'), (u'http://pan.baidu.com/s/1slhDEjj', u'zn49'), (u'https://pan.baidu.com/s/1jIL49MY', u'sxy3')]}

# %%
from selenium import webdriver
from selenium.webdriver.support.select import Select
import os,time
import urllib
url_main= 'http://m.mei123478.com/?s='
searchKey = u'jigsaw'
pre_url = url_main + urllib.quote_plus(searchKey.encode('utf8'))

# 第一部分：获取检索项进行重构url
driver_detail = webdriver.PhantomJS()
driver_detail.get(pre_url)
# url = driver_detail.find_element_by_xpath("//div[@class='article']/h2/a").get_attribute('href')

# print url

article_list = driver_detail.find_elements_by_xpath("//div[@class='article']/h2/a")

url_find = 'NoFound'
for article in article_list:
    if searchKey.encode('utf8') in article.text.encode('utf8'):
        url_find = article.get_attribute('href')
        break

print url_find   
driver_detail.quit()
#driver_detail.get(url)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-64-0dc1f6354a80> in <module>()
#       9 # 第一部分：获取检索项进行重构url
#      10 driver_detail = webdriver.PhantomJS()
# ---> 11 driver_detail.get(pre_url)
#      12 # url = driver_detail.find_element_by_xpath("//div[@class='article']/h2/a").get_attribute('href')
#      13
#
# /Users/mrlevo/anaconda/lib/python2.7/site-packages/selenium/webdriver/remote/webdriver.pyc in get(self, url)
#     266         Loads a web page in the current browser session.
#     267         """
# --> 268         self.execute(Command.GET, {'url': url})
#     269
#     270     @property
#
# /Users/mrlevo/anaconda/lib/python2.7/site-packages/selenium/webdriver/remote/webdriver.pyc in execute(self, driver_command, params)
#     252
#     253         params = self._wrap_value(params)
# --> 254         response = self.command_executor.execute(driver_command, params)
#     255         if response:
#     256             self.error_handler.check_response(response)
#
# /Users/mrlevo/anaconda/lib/python2.7/site-packages/selenium/webdriver/remote/remote_connection.pyc in execute(self, command, params)
#     462         path = string.Template(command_info[1]).substitute(params)
#     463         url = '%s%s' % (self._url, path)
# --> 464         return self._request(command_info[0], url, body=data)
#     465
#     466     def _request(self, method, url, body=None):
#
# /Users/mrlevo/anaconda/lib/python2.7/site-packages/selenium/webdriver/remote/remote_connection.pyc in _request(self, method, url, body)
#     524                 opener = url_request.build_opener(url_request.HTTPRedirectHandler(),
#     525                                                   HttpErrorHandler())
# --> 526             resp = opener.open(request, timeout=self._timeout)
#     527             statuscode = resp.code
#     528             if not hasattr(resp, 'getheader'):
#
# /Users/mrlevo/anaconda/lib/python2.7/urllib2.pyc in open(self, fullurl, data, timeout)
#     427             req = meth(req)
#     428
# --> 429         response = self._open(req, data)
#     430
#     431         # post-process response
#
# /Users/mrlevo/anaconda/lib/python2.7/urllib2.pyc in _open(self, req, data)
#     445         protocol = req.get_type()
#     446         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 447                                   '_open', req)
#     448         if result:
#     449             return result
#
# /Users/mrlevo/anaconda/lib/python2.7/urllib2.pyc in _call_chain(self, chain, kind, meth_name, *args)
#     405             func = getattr(handler, meth_name)
#     406
# --> 407             result = func(*args)
#     408             if result is not None:
#     409                 return result
#
# /Users/mrlevo/anaconda/lib/python2.7/urllib2.pyc in http_open(self, req)
#    1226
#    1227     def http_open(self, req):
# -> 1228         return self.do_open(httplib.HTTPConnection, req)
#    1229
#    1230     http_request = AbstractHTTPHandler.do_request_
#
# /Users/mrlevo/anaconda/lib/python2.7/urllib2.pyc in do_open(self, http_class, req, **http_conn_args)
#    1199         else:
#    1200             try:
# -> 1201                 r = h.getresponse(buffering=True)
#    1202             except TypeError: # buffering kw not supported
#    1203                 r = h.getresponse()
#
# /Users/mrlevo/anaconda/lib/python2.7/httplib.pyc in getresponse(self, buffering)
#    1119
#    1120         try:
# -> 1121             response.begin()
#    1122             assert response.will_close != _UNKNOWN
#    1123             self.__state = _CS_IDLE
#
# /Users/mrlevo/anaconda/lib/python2.7/httplib.pyc in begin(self)
#     436         # read until we get a non-100 response
#     437         while True:
# --> 438             version, status, reason = self._read_status()
#     439             if status != CONTINUE:
#     440                 break
#
# /Users/mrlevo/anaconda/lib/python2.7/httplib.pyc in _read_status(self)
#     392     def _read_status(self):
#     393         # Initialize with Simple-Response defaults
# --> 394         line = self.fp.readline(_MAXLINE + 1)
#     395         if len(line) > _MAXLINE:
#     396             raise LineTooLong("header line")
#
# /Users/mrlevo/anaconda/lib/python2.7/socket.pyc in readline(self, size)
#     478             while True:
#     479                 try:
# --> 480                     data = self._sock.recv(self._rbufsize)
#     481                 except error, e:
#     482                     if e.args[0] == EINTR:
#
# KeyboardInterrupt:

# %%
# -*- coding: utf-8 -*-
# 获取页面隐藏元素，网盘链接及密码
# 测试页面：http://m.mei123478.com/
# 页面描述：网盘链接和密码隐藏，所以第一步需要注入js进行显示，然后正常进行文本解析，因为字段比较简单，所以直接字符串解析了
# 注意：使用phantomjs等待时间比较久,所以调试是一个比较累人的工作
# 2017.11.20: 修复多值检索项的匹配问题
# 2017.11.27: 重构检索结构

from selenium import webdriver
from selenium.webdriver.support.select import Select
import os,time
import urllib

def getUP(searchKey):
    '''
    Input:searchKey u'生活大爆炸'
    Return: {searchKey:[(introword,link,password),]}
    
    '''
    url_main= 'http://m.mei123478.com/?s='
    pre_url = url_main + urllib.quote_plus(searchKey.encode('utf8'))

    # 第一部分：获取检索项进行重构url
    driver_detail = webdriver.PhantomJS()
    driver_detail.get(pre_url)
    article_list = driver_detail.find_elements_by_xpath("//div[@class='article']/h2/a")
    url_find = 'NoFound'
    for article in article_list:
        if searchKey.encode('utf8') in article.text.encode('utf8'):
            url_find = article.get_attribute('href')
            break

#     print url_find 
    
    if url_find != 'NoFound':
        driver_detail.get(url_find)

        # 第二部分：将隐藏元素显现，设置display='block'
        # thanks for :https://www.cnblogs.com/fnng/p/5365900.html
        # 注入js脚本，开启所有包含网盘内容的h2标签
        js = '''
        var urlpw = document.querySelectorAll("h2");
        var size_ = urlpw.length;
        for (i=0;i<size_;i++){urlpw[i].style.display='block'}
        '''
        driver_detail.execute_script(js)

        # 第三部分，解析隐藏字段，解析出网盘链接和密码
        #url_ = driver_detail.find_elements_by_xpath("//h2[@style='display: block;']")
        url_ = driver_detail.find_elements_by_xpath("//span[@style='color: #ff0000;']")  # 使用颜色属性，缩小范围
        urlpw = []    

        for hide in url_:
            innerHtml = hide.get_attribute("innerHTML")
            #print hide.text  # 度盘点我  密码: siua
            if 'http' in innerHtml:
                url = innerHtml.split("href=\"")[-1].split("\">")[0]
                introword = innerHtml.split("href=\"")[-1].split("\">")[-1].split("<")[0].strip()
                #print url
                if u'密码' in innerHtml:
                    pw = hide.text[-4:]
                    #print pw
                else:
                    #print 'No Password,just watch'
                    pw = 'NoPW'
                urlpw.append((introword,url,pw))

        driver_detail.quit()
        return {searchKey:urlpw}
    else:
        return 'No Found or change the title try again!'

if __name__ == '__main__':
    
    test = [u'美国恐怖故事']#,u'当你沉睡时', u'无耻之徒',u'生活大爆炸']
    for i in test:
        urlpw = getUP(i)
        print urlpw
        print '-----'
#     urlpw = getUP(u'美国恐怖故事')
#     print urlpw
# Out:
# {u'\u7f8e\u56fd\u6050\u6016\u6545\u4e8b': [(u'\u7f8e\u6050\u767e\u5ea6\u4e91', u'http://pan.baidu.com/s/1mhCJkes', u'i2jt'), (u'\u7b2c\u516d\u5b63\u5907\u7528', u'http://pan.baidu.com/s/1slhDEjj', u'zn49'), (u'\u7b2c\u4e03\u5b63\u94fe\u63a5', u'https://pan.baidu.com/s/1jIL49MY', u'sxy3')]}
# -----

# %%
for i in range(len(urlpw[u'美国恐怖故事'])):
    print urlpw[u'美国恐怖故事'][i][0]
# Out:
# 美恐百度云
# 第六季备用
# 第七季链接

# %%
from selenium import webdriver
import webbrowser
file_name = u'美国恐怖故事'
pan_url = 'http://pan.baidu.com/s/1slhDEjj'
pan_url = 'https://pan.baidu.com/s/1jIL49MY'
# https://pan.baidu.com/share/init?surl=slhDEjj
pan_url =  'https://pan.baidu.com/share/init?surl=jIL49MY'
# pan_url = 'http://m.mei123478.com/'
pan_pw = 'zn49'
# pan_url = 'https://pan.baidu.com/'
try:
#     driver_save = webdriver.PhantomJS()
#     driver_save.get(pan_url)
#     elem_psw = driver_save.find_element_by_xpath("//div[@class='article']")
#     print elem_psw.text
#     elem_psw.send_keys(pan_pw)
    
#     click_second = driver_save.find_element_by_xpath("//span[@class='g-button-right']/span")
#     click_second.click()
    #browser = webdriver.Chrome(executable_path = '/Users/mrlevo/Documents/Driver/chromedriver') 
    #browser.get(pan_url)
    #browser.maximize_window()
    webbrowser.open_new(pan_url)
#     while True:
#         if browser.title == u'百度网盘-全部文件' :
#             cookies = browser.get_cookies()
#             cookieStr = ''
#             for x in cookies :
#                 cookieStr += x['name'] + '=' + x['value'] + '; '

#             result = {'stat': 1, 'msg': '获取成功'}
#             print cookieStr
#             break
#         print 'here'
#         time.sleep(5)
    
except Exception as ex:
    print ex


# finally:
#     browser.quit()

# %%
import urllib
import urllib2
import re
import ssl
import os

def getPage (url, requestHeader = [], postData = {}) :
    if postData == {} :
        request = urllib2.Request(url)
    elif isinstance(postData, basestring) :
        request = urllib2.Request(url, postData)
    else :
        request = urllib2.Request(url, urllib.urlencode(postData))

    for x in requestHeader :
        headerType = x.split(':')[0]
        headerCon = x.replace(headerType + ':', '')
        request.add_header(headerType, headerCon)

    try : 
        ctx = ssl.create_default_context()
        ctx.check_hostname = False
        ctx.verify_mode = ssl.CERT_NONE
        response = urllib2.urlopen(request, context = ctx)
        header = response.headers
        body = response.read()
        code = response.code
    except urllib2.HTTPError as e:
        header = e.headers
        body = e.read()
        code = e.code

    result = {
        'code': code,
        'header': header,
        'body': body
    }

    return result

cookie = '''
Cookie:PANPSC=16051443732609861351%3AmTP0WM%2Fa3Kxi5hMup6rmZ%2Bn90oj%2BY%2FIsvKIVNOUgoRf2cOIXk9OomVYNY67F0at5LFDH6zIpNF7xTJ3v1z1m%2Bode8CdIjODH2f1O%2FWlhg848%2FDQ2UZ6kbXxJOkmp79ZELPY%2BF1C2z9fyZrW4Cjmr5CtY6oDerc8JwO6IUlyEdXI5u4Owi7HyOET6EtWQMy2KSSzrHYofj1Q%3D; cflag=15%3A3; FP_LASTTIME=1508205585364; Hm_lvt_7a3960b6f067eb0085b7f96ff5e660b0=1508205599; SCRC=b0084404138dd6f7b1831ef1572abb43; STOKEN=3747deddea4dbfd1d45a938273fda5b6eca16d2d15be2c9f9d255c33009d8751; Hm_lpvt_7a3960b6f067eb0085b7f96ff5e660b0=1508205599; PANWEB=1; pan_login_way=1; BDUSS=d1a3dxakxNdUd0cVNnT2RQd3JSajJsSTNNWX5TVGc3VzlXUk9EQUJBTWI4UXhhSVFBQUFBJCQAAAAAAAAAAAEAAABAoq4uuf7Kv8bmy7Xf9wAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAABtk5VkbZOVZST; panlogin_animate_showed=1; FP_UID=79742f1da033f608806f7d633c6a65f4; BAIDUID=90FAE382EDABFBD1A3316A64286AE349:FG=1;'''
bdApi = 'https://yun.baidu.com/disk/home?errno=0&errmsg=Auth%20Login%20Sucess&&bduss=&ssnerror=0'
requestHeader = [
    cookie.strip(),
    'Host:pan.baidu.com',
    'Origin:https://pan.baidu.com',
    'Referer:https://pan.baidu.com/disk/home',
    'User-Agent:netdisk;5.3.4.5;PC;PC-Windows;5.1.2600;WindowsBaiduYunGuanJia'
]
html = getPage(bdApi, requestHeader)

# %%
html
# Out:
# {'body': '\n<!DOCTYPE html>\n<html>\n<head>\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8"/>\n<meta http-equiv="X-UA-Compatible" content="IE=7,9,10,11"/>\n<meta name="renderer" content="webkit">\n<link rel="dns-prefetch" href="//pcs.baidu.com"/>\n<link rel="dns-prefetch" href="//pcsdata.baidu.com"/>\n<link rel="dns-prefetch" href="//passport.baidu.com"/>\n<link rel="dns-prefetch" href="//yun.baidu.com"/>\n<link rel="dns-prefetch" href="//d.pcs.baidu.com"/>\n<link rel="dns-prefetch" href="//c.pcs.baidu.com"/>\n<link rel="dns-prefetch" href="//webpush.pan.baidu.com"/>\n<link rel="dns-prefetch" href="//hm.baidu.com"/>\n<link rel="shortcut icon" href="/box-static/disk-system/images/favicon.ico"/>\n<title>\xe7\x99\xbe\xe5\xba\xa6\xe7\xbd\x91\xe7\x9b\x98-\xe5\x85\xa8\xe9\x83\xa8\xe6\x96\x87\xe4\xbb\xb6</title>\n<script type="text/javascript" src="/box-static/base/js/lib/mod_6f61578.js" ></script>\n\n\n<meta content="b31ebb7c3759312418b3645de4991aef" name="baidu-tc-verification"/>\n<meta content="max-age=30" http-equiv="Cache-Control"/>\n<meta name="viewport" content="width=device-width, initial-scale=1, user-scalable=0">\n<meta content="\xe7\xbd\x91\xe7\x9b\x98,\xe7\x99\xbe\xe5\xba\xa6\xe7\xbd\x91\xe7\x9b\x98,\xe7\x99\xbe\xe5\xba\xa6\xe4\xba\x91,\xe7\xbd\x91\xe7\xbb\x9cU\xe7\x9b\x98,\xe7\xbd\x91\xe7\xbb\x9c\xe7\xa1\xac\xe7\x9b\x98,\xe5\x85\x8d\xe8\xb4\xb9\xe7\xbd\x91\xe7\x9b\x98,\xe7\xbd\x91\xe7\x9b\x98\xe4\xb8\x8b\xe8\xbd\xbd,\xe7\xbd\x91\xe7\x9b\x98\xe8\xb5\x84\xe6\xba\x90,\xe5\x90\x8c\xe6\xad\xa5,\xe4\xba\x91\xe5\xad\x98\xe5\x82\xa8,\xe5\xa4\x96\xe9\x93\xbe\xe5\x88\x86\xe4\xba\xab,\xe7\xa6\xbb\xe7\xba\xbf\xe4\xb8\x8b\xe8\xbd\xbd" name="keywords"/>\n<meta content="2T\xe7\x9a\x84\xe5\x85\x8d\xe8\xb4\xb9\xe5\xad\x98\xe5\x82\xa8\xe7\xa9\xba\xe9\x97\xb4" name="description"/>\n\n<link rel="stylesheet" type="text/css" href="/box-static/disk-system/css/alpha_8f7c217.css"/>\n<style type="text/css">.default-large{background:url(/box-static/disk-system/widget/pageModule/list/img/Misc_54_f86ddc2.png) center no-repeat}.dir-large{background:url(/box-static/disk-system/widget/pageModule/list/img/Folder_54_fe544cc.png) center no-repeat}.dir-share-large{background:url(/box-static/disk-system/widget/pageModule/list/img/Share_54_142956d.png) center no-repeat}.dir-cang-large{background:url(/box-static/disk-system/widget/pageModule/list/img/Collection_54_7849a8d.png) center no-repeat}.dir-card-large{background:url(/box-static/disk-system/widget/pageModule/list/img/card_54_b068d33.png) center no-repeat}.dir-app-large,.dir-apps-large{background:url(/box-static/disk-system/widget/pageModule/list/img/MyData_54_cb4dfe9.png) center no-repeat}.dir-backup-large{background:url(/box-static/disk-system/widget/pageModule/list/img/PC_54_e2efc5f.png) center no-repeat}.dir-multi-large{background:url(/box-static/disk-system/widget/pageModule/list/img/gridIcon_7165cae.png) -600px -100px no-repeat}.dir-phone-large{background:url(/box-static/disk-system/widget/pageModule/list/img/Phone_54_a774466.png) center no-repeat}.dir-phone-small{background:url(/box-static/disk-system/widget/pageModule/list/img/Phone_24_365064e.png?__sprite) center no-repeat}.default-small{background:url(/box-static/disk-system/widget/pageModule/list/img/Misc ...
#  'code': 200,
#  'header': <httplib.HTTPMessage instance at 0x10a1cdc68>}

# %%
 html['body']
# Out:
# '\n<!DOCTYPE html>\n<html>\n<head>\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8"/>\n<meta http-equiv="X-UA-Compatible" content="IE=7,9,10,11"/>\n<meta name="renderer" content="webkit">\n<link rel="dns-prefetch" href="//pcs.baidu.com"/>\n<link rel="dns-prefetch" href="//pcsdata.baidu.com"/>\n<link rel="dns-prefetch" href="//passport.baidu.com"/>\n<link rel="dns-prefetch" href="//yun.baidu.com"/>\n<link rel="dns-prefetch" href="//d.pcs.baidu.com"/>\n<link rel="dns-prefetch" href="//c.pcs.baidu.com"/>\n<link rel="dns-prefetch" href="//webpush.pan.baidu.com"/>\n<link rel="dns-prefetch" href="//hm.baidu.com"/>\n<link rel="shortcut icon" href="/box-static/disk-system/images/favicon.ico"/>\n<title>\xe7\x99\xbe\xe5\xba\xa6\xe7\xbd\x91\xe7\x9b\x98-\xe5\x85\xa8\xe9\x83\xa8\xe6\x96\x87\xe4\xbb\xb6</title>\n<script type="text/javascript" src="/box-static/base/js/lib/mod_6f61578.js" ></script>\n\n\n<meta content="b31ebb7c3759312418b3645de4991aef" name="baidu-tc-verification"/>\n<meta content="max-age=30" http-equiv="Cache-Control"/>\n<meta name="viewport" content="width=device-width, initial-scale=1, user-scalable=0">\n<meta content="\xe7\xbd\x91\xe7\x9b\x98,\xe7\x99\xbe\xe5\xba\xa6\xe7\xbd\x91\xe7\x9b\x98,\xe7\x99\xbe\xe5\xba\xa6\xe4\xba\x91,\xe7\xbd\x91\xe7\xbb\x9cU\xe7\x9b\x98,\xe7\xbd\x91\xe7\xbb\x9c\xe7\xa1\xac\xe7\x9b\x98,\xe5\x85\x8d\xe8\xb4\xb9\xe7\xbd\x91\xe7\x9b\x98,\xe7\xbd\x91\xe7\x9b\x98\xe4\xb8\x8b\xe8\xbd\xbd,\xe7\xbd\x91\xe7\x9b\x98\xe8\xb5\x84\xe6\xba\x90,\xe5\x90\x8c\xe6\xad\xa5,\xe4\xba\x91\xe5\xad\x98\xe5\x82\xa8,\xe5\xa4\x96\xe9\x93\xbe\xe5\x88\x86\xe4\xba\xab,\xe7\xa6\xbb\xe7\xba\xbf\xe4\xb8\x8b\xe8\xbd\xbd" name="keywords"/>\n<meta content="2T\xe7\x9a\x84\xe5\x85\x8d\xe8\xb4\xb9\xe5\xad\x98\xe5\x82\xa8\xe7\xa9\xba\xe9\x97\xb4" name="description"/>\n\n<link rel="stylesheet" type="text/css" href="/box-static/disk-system/css/alpha_8f7c217.css"/>\n<style type="text/css">.default-large{background:url(/box-static/disk-system/widget/pageModule/list/img/Misc_54_f86ddc2.png) center no-repeat}.dir-large{background:url(/box-static/disk-system/widget/pageModule/list/img/Folder_54_fe544cc.png) center no-repeat}.dir-share-large{background:url(/box-static/disk-system/widget/pageModule/list/img/Share_54_142956d.png) center no-repeat}.dir-cang-large{background:url(/box-static/disk-system/widget/pageModule/list/img/Collection_54_7849a8d.png) center no-repeat}.dir-card-large{background:url(/box-static/disk-system/widget/pageModule/list/img/card_54_b068d33.png) center no-repeat}.dir-app-large,.dir-apps-large{background:url(/box-static/disk-system/widget/pageModule/list/img/MyData_54_cb4dfe9.png) center no-repeat}.dir-backup-large{background:url(/box-static/disk-system/widget/pageModule/list/img/PC_54_e2efc5f.png) center no-repeat}.dir-multi-large{background:url(/box-static/disk-system/widget/pageModule/list/img/gridIcon_7165cae.png) -600px -100px no-repeat}.dir-phone-large{background:url(/box-static/disk-system/widget/pageModule/list/img/Phone_54_a774466.png) center no-repeat}.dir-phone-small{background:url(/box-static/disk-system/widget/pageModule/list/img/Phone_24_365064e.png?__sprite) center no-repeat}.default-small{background:url(/box-static/disk-system/widget/pageModule/list/img/Misc_24_15641 ...

# %%
import re
yunData = re.findall(r"var context\=([\s\S]*?)yunData", html['body'])

# %%
yunData = yunData[0]

# %%
yunData
# Out:
# '{"loginstate":1,"username":"\\u54c8\\u58eb\\u5947\\u8bf4\\u55b5","third":0,"flag":1,"file_list":null,"uk":2720665201,"task_key":"45e5eb81fb7c3e31a92a813443be64a7ea8b5c3c","task_time":1511532711,"sampling":{"expvar":["video_high_speed","disk_timeline"]},"bdstoken":"a428fad62af797e4d9f0614b49e46441","is_vip":0,"bt_paths":null,"applystatus":1,"sign1":"abd8ca387f27faacddc71a93f0236088a7bb26fe","sign2":"function s(j,r){var a=[];var p=[];var o=\\"\\";var v=j.length;for(var q=0;q<256;q++){a[q]=j.substr((q%v),1).charCodeAt(0);p[q]=q}for(var u=q=0;q<256;q++){u=(u+p[q]+a[q])%256;var t=p[q];p[q]=p[u];p[u]=t}for(var i=u=q=0;q<r.length;q++){i=(i+1)%256;u=(u+p[i])%256;var t=p[i];p[i]=p[u];p[u]=t;k=p[((p[i]+p[u])%256)];o+=String.fromCharCode(r.charCodeAt(q)^k)}return o};","sign3":"d76e889b6aafd3087ac3bd56f4d4053a","timestamp":1511532712,"timeline_status":1,"face_status":0,"srv_ts":1511532712,"need_tips":null,"is_year_vip":0,"show_vip_ad":0,"vip_end_time":null,"is_evip":0,"is_svip":0,"is_auto_svip":0,"activity_status":0,"photo":"https:\\/\\/ss0.bdstatic.com\\/7Ls0a8Sm1A5BphGlnYG\\/sys\\/portrait\\/item\\/40a2ae2e.jpg","curr_activity_code":0,"activity_end_time":0,"token":"8df9uwJbUW4UyF3r1zOpn61k50yNci5S6Mvtlu3MAt3woISb8sOYdbmtGW6eLlbYIEcol7HPVi3wTsZDmnZPJNE4uACcT9gbPZTPMdypUgK9QFL1PivaZY1N95Tr0JMzJVF5RjD8iYlN3sfEGUEiYRD3NjMKFxBJJ2XyhEke1He2rms+UEoinHwU5u1Q\\/fI6EAulhNI8p9Qa+WjuZSwwnZWloPn9Gudc6LL+Rw\\/WFPBP93q7OM3N\\/pl+ouXtYlXepMmMiLWu\\/pOCQsgVlK9YGVFQOdONmLKw6Qg","sharedir":0,"pansuk":"nIe13Z5zZ1vjXHmQrEoE_A","urlparam":[],"XDUSS":"pansec_DCb740ccc5511e5e8fedcff06b081203-5zLpASs7Na9ojbg55BxvQYRDcHf68DvKHkOw5Vl6Fbi42reXHIUtiqbN1NZGwKSVYM1zNmmTCU13tW0KQV73cam9hmBQkQzmQALFnw7qE5PuU%2Fze5e2Bzo5ED0DCx0QUEyvNyImqsScVcu7wKDENfwpij71u1lzNRXj%2Fth1Q2nhyD9umGbxLPNvx89s1rr7QXIH9V33Hoh1nubGHY4TYw%2F%2F4PPvbMKwQfzQp4ih3wLR2TRwD5tgvMiWmVuBWMCjPrb5FhS9%2Fq7wjfzxM5CfpHg%3D%3D"};\n            var '

# %%
re.findall(r'"username":"(.*?)"', yunData)[0]
# Out:
# '\\u54c8\\u58eb\\u5947\\u8bf4\\u55b5'

# %%
bdSign1 = re.findall(r'"sign1":"(.*?)"', yunData)[0]

# %%
bdSign1
# Out:
# 'abd8ca387f27faacddc71a93f0236088a7bb26fe'

# %%
token = re.findall(r'"bdstoken":"(.*?)"', yunData)[0]

# %%
token
# Out:
# 'a428fad62af797e4d9f0614b49e46441'

# %%
playurl = 'https://yun.baidu.com/rest/2.0/services/cloud_dl?need_task_info=1&status=255&start=0&limit=10&method=list_task&app_id=250528&channel=chunlei&web=1&app_id=250528&bdstoken={}&clienttype=0'.format(token)

# %%
requestHeader = [
    cookie.strip(),
    'Host:pan.baidu.com',
    'Origin:https://pan.baidu.com',
    'Referer:https://pan.baidu.com/disk/home',
    'User-Agent:netdisk;5.3.4.5;PC;PC-Windows;5.1.2600;WindowsBaiduYunGuanJia'
]
html = getPage(playurl, requestHeader)

# %%
info = json.JSONDecoder().decode(html['body'])
taskInfo = info['task_info']

# %%
taskInfo
# Out:
# [{u'callback': u'',
#   u'create_time': u'1511535636',
#   u'od_type': u'3',
#   u'rate_limit': u'0',
#   u'save_path': u'/MovieCatcherFiles/\u751f\u6d3b\u5927\u7206\u70b8.The.Big.Bang.Theory.S09E14.\u4e2d\u82f1\u5b57\u5e55.WEB-HR.AAC.1024X576.x264.mp4',
#   u'source_url': u'ed2k://|file|%E7%94%9F%E6%B4%BB%E5%A4%A7%E7%88%86%E7%82%B8.The.Big.Bang.Theory.S09E14.%E4%B8%AD%E8%8B%B1%E5%AD%97%E5%B9%95.WEB-HR.AAC.1024X576.x264.mp4|187997989|c891e0151edfcdb7acdcc70de8aa38b0|h=7zae27ez7vokfmrtos572p2b7yenkvps|/',
#   u'status': u'0',
#   u'task_id': u'2136050254',
#   u'task_name': u'\u751f\u6d3b\u5927\u7206\u70b8.The.Big.Bang.Theory.S09E14.\u4e2d\u82f1\u5b57\u5e55.WEB-HR.AAC.1024X576.x264.mp4',
#   u'timeout': u'0'},
#  {u'callback': u'',
#   u'create_time': u'1511534178',
#   u'od_type': u'3',
#   u'rate_limit': u'0',
#   u'save_path': u'/MovieCatcherFiles/\u751f\u6d3b\u5927\u7206\u70b8.The.Big.Bang.Theory.S09E18.\u4e2d\u82f1\u5b57\u5e55.WEB-HR.AAC.1024X576.x264.mp4',
#   u'source_url': u'ed2k://|file|%E7%94%9F%E6%B4%BB%E5%A4%A7%E7%88%86%E7%82%B8.The.Big.Bang.Theory.S09E18.%E4%B8%AD%E8%8B%B1%E5%AD%97%E5%B9%95.WEB-HR.AAC.1024X576.x264.mp4|192481720|e78ed85d06891b35e12c66491820e0f8|h=3722f57abpv37a55j3zmu72djcscjkya|/',
#   u'status': u'0',
#   u'task_id': u'2135986827',
#   u'task_name': u'\u751f\u6d3b\u5927\u7206\u70b8.The.Big.Bang.Theory.S09E18.\u4e2d\u82f1\u5b57\u5e55.WEB-HR.AAC.1024X576.x264.mp4',
#   u'timeout': u'0'},
#  {u'callback': u'',
#   u'create_time': u'1511528583',
#   u'od_type': u'3',
#   u'rate_limit': u'0',
#   u'save_path': u'/MovieCatcherFiles/\u5f53\u4f60\u6c89\u7761\u65f6.E19.\u97e9\u8bed\u4e2d\u5b57.720p.HDTV.\u521d\u5fc3\u5b57\u5e55\u7ec4.V2.mp4',
#   u'source_url': u'ed2k://|file|\u5f53\u4f60\u6c89\u7761\u65f6.E19.\u97e9\u8bed\u4e2d\u5b57.720p.HDTV.\u521d\u5fc3\u5b57\u5e55\u7ec4.V2.mp4|605622994|97ad8074dfe1d2bcf8c15f61943a8cb3|h=lms37x5qy6aurpa3ife72mcmdrnvswkd|/',
#   u'status': u'0',
#   u'task_id': u'2135725415',
#   u'task_name': u'\u5f53\u4f60\u6c89\u7761\u65f6.E19.\u97e9\u8bed\u4e2d\u5b57.720p.HDTV.\u521d\u5fc3\u5b57\u5e55\u7ec4.V2.mp4',
#   u'timeout': u'0'},
#  {u'callback': u'',
#   u'create_time': u'1511526766',
#   u'od_type': u'3',
#   u'rate_limit': u'0',
#   u'save_path': u'/MovieCatcherFiles/\u5f53\u4f60\u6c89\u7761\u65f6.E19.\u97e9\u8bed\u4e2d\u5b57.720p.HDTV.\u521d\u5fc3\u5b57\u5e55\u7ec4.V2.mp4',
#   u'source_url': u'ed2k://|file|\u5f53\u4f60\u6c89\u7761\u65f6.E19.\u97e9\u8bed\u4e2d\u5b57.720p.HDTV.\u521d\u5fc3\u5b57\u5e55\u7ec4.V2.mp4|605622994|97ad8074dfe1d2bcf8c15f61943a8cb3|h=lms37x5qy6aurpa3ife72mcmdrnvswkd|/',
#   u'status': u'0',
#   u'task_id': u'2135641987',
#   u'task_name': u'\u5f53\u4f60\u6c89\u7761\u65f6.E19.\u97e9\u8bed\u4e2d\u5b57.720p.HDTV.\u521d\u5fc3\u5b57\u5e55\u7ec4.V2.mp4',
#   u'timeout': u'0'},
#  {u'callback': u'',
#   u'create_time': u'1511526651',
#   u'od_type': u'3',
#   u'rate_limit': u'0',
#   u'save_path': u'/MovieCatcherFiles/\u5f53\u4f60\u6c89\u7761\u65f6.E20.\u97e9\u8bed\u4e2d\u5b57.720p.HDTV.\u521d\u5fc3\u5b57\u5e55\u7ec4.V2.mp4',
#   u'source_url': u'ed2k://|file|\u5f53\u4f60\u6c89\u7761\u65f6.E20.\u97e9\u8bed\u4e2d\u5b57.720p.HDTV.\u521d\u5fc3\u5b57\u5e55\u7ec4.V2.mp4|615210363|93147e497f990c0535167d807fa7a6d3|h=bgbc66xknvhlkifenegnuuhould2p3vv|/',
#   u'status': u'0',
#   u'task_id': u'2135636843',
#   u'task_name': u'\u5f53\u4f60\u6c89\u7761\u65f6.E20.\u97e9\u8bed\u4e2d\u5b57.720p.HDTV.\u521d\u5fc3\u5b57\u5e55\u7ec4.V2.mp4',
#   u'timeout': u'0'},
#  {u'callback': u'',
#   u'create_time': u'1511526639',
#   u'od_type': u'3',
#   u'rate_limit': u'0',
#   u'save_path': u'/MovieCatcherFiles/\u5f53\u4f60\u6c89\u7761\u65f6.E21.\u97e9\u8bed\u4e2d\u5b57.720p.HDTV.\u521d\u5fc3\u5b57\u5e55\u7ec4.mp4',
#   u'source_url': u'ed2k://|file|\u5f53\u4f60\u6c89\u7761\u65f6.E21.\u97e9\u8bed\u4e2d\u5b57.720p.HDTV.\u521d\u5fc3\u5b57\u5e55\u7ec4.mp4|490606746|e6b7e57c9c477643e1527f3da0b8ce70|h=txoe3tlxnjpejmta6dkxj5iyzydv6lrp|/',
#   u'status': u'1',
#   u'task_id': u'2135636351',
#   u'task_name': u'\u5f53\u4f60\u6c89\u7761\u65f6.E21.\u97e9\u8bed\u4e2d\u5b57.720p.HDTV.\u521d\u5fc3\u5b57\u5e55\u7ec4.mp4',
#   u'timeout': u'0'},
#  {u'callback': u'',
#   u'create_time': u'1511525894',
#   u'od_type': u'3',
#   u'rate_limit': u'0',
#   u'save_path': u'/MovieCatcherFiles/\u5f53\u4f60\u6c89\u7761\u65f6.E19.\u97e9\u8bed\u4e2d\u5b57.720p.HDTV.\u521d\u5fc3\u5b57\u5e55\u7ec4.V2.mp4',
#   u'source_url': u'ed2k://|file|\u5f53\u4f60\u6c89\u7761\u65f6.E19.\u97e9\u8bed\u4e2d\u5b57.720p.HDTV.\u521d\u5fc3\u5b57\u5e55\u7ec4.V2.mp4|605622994|97ad8074dfe1d2bcf8c15f61943a8cb3|h=lms37x5qy6aurpa3ife72mcmdrnvswkd|/',
#   u'status': u'0',
#   u'task_id': u'2135603090',
#   u'task_name': u'\u5f53\u4f60\u6c89\u7761\u65f6.E19.\u97e9\u8bed\u4e2d\u5b57.720p.HDTV.\u521d\u5fc3\u5b57\u5e55\u7ec4.V2.mp4',
#   u'timeout': u'0'},
#  {u'callback': u'',
#   u'create_time': u'1511525875',
#   u'od_type': u'3',
#   u'rate_limit': u'0',
#   u'save_path': u'/MovieCatcherFiles/\u5f53\u4f60\u6c89\u7761\u65f6.E21.\u97e9\u8bed\u4e2d\u5b57.720p.HDTV.\u521d\u5fc3\u5b57\u5e55\u7ec4.mp4',
#   u'source_url': u'ed2k://|file|\u5f53\u4f60\u6c89\u7761\u65f6.E21.\u97e9\u8bed\u4e2d\u5b57.720p.HDTV.\u521d\u5fc3\u5b57\u5e55\u7ec4.mp4|490606746|e6b7e57c9c477643e1527f3da0b8ce70|h=txoe3tlxnjpejmta6dkxj5iyzydv6lrp|/',
#   u'status': u'1',
#   u'task_id': u'2135602302',
#   u'task_name': u'\u5f53\u4f60\u6c89\u7761\u65f6.E21.\u97e9\u8bed\u4e2d\u5b57.720p.HDTV.\u521d\u5fc3\u5b57\u5e55\u7ec4.mp4',
#   u'timeout': u'0'},
#  {u'callback': u'',
#   u'create_time': u'1511523944',
#   u'od_type': u'3',
#   u'rate_limit': u'0',
#   u'save_path': u'/MovieCatcherFiles/\u5f53\u4f60\u6c89\u7761\u65f6.E20.\u97e9\u8bed\u4e2d\u5b57.720p.HDTV.\u521d\u5fc3\u5b57\u5e55\u7ec4.V2.mp4',
#   u'source_url': u'ed2k://|file|\u5f53\u4f60\u6c89\u7761\u65f6.E20.\u97e9\u8bed\u4e2d\u5b57.720p.HDTV.\u521d\u5fc3\u5b57\u5e55\u7ec4.V2.mp4|615210363|93147e497f990c0535167d807fa7a6d3|h=bgbc66xknvhlkifenegnuuhould2p3vv|/',
#   u'status': u'0',
#   u'task_id': u'2135522698',
#   u'task_name': u'\u5f53\u4f60\u6c89\u7761\u65f6.E20.\u97e9\u8bed\u4e2d\u5b57.720p.HDTV.\u521d\u5fc3\u5b57\u5e55\u7ec4.V2.mp4',
#   u'timeout': u'0'},
#  {u'callback': u'',
#   u'create_time': u'1510068532',
#   u'od_type': u'3',
#   u'rate_limit': u'0',
#   u'save_path': u'/MovieCatcherFiles/\u9ed1\u955c.Black.Mirror.S03E02.\u4e2d\u82f1\u5b57\u5e55.WEB-HR.AAC.1024X576.x264.mp4',
#   u'source_url': u'ed2k://|file|%E9%BB%91%E9%95%9C.Black.Mirror.S03E02.%E4%B8%AD%E8%8B%B1%E5%AD%97%E5%B9%95.WEB-HR.AAC.1024X576.x264.mp4|566528765|908100c3f6d1d711acfbbe4c92fdc689|h=fcg2lromtic26a23fcw7bzfak7ba2gjz|/',
#   u'status': u'0',
#   u'task_id': u'2108366567',
#   u'task_name': u'\u9ed1\u955c.Black.Mirror.S03E02.\u4e2d\u82f1\u5b57\u5e55.WEB-HR.AAC.1024X576.x264.mp4',
#   u'timeout': u'0'}]

# %%
info
# Out:
# {u'request_id': 7605674406119543902,
#  u'task_info': [{u'callback': u'',
#    u'create_time': u'1511528583',
#    u'od_type': u'3',
#    u'rate_limit': u'0',
#    u'save_path': u'/MovieCatcherFiles/\u5f53\u4f60\u6c89\u7761\u65f6.E19.\u97e9\u8bed\u4e2d\u5b57.720p.HDTV.\u521d\u5fc3\u5b57\u5e55\u7ec4.V2.mp4',
#    u'source_url': u'ed2k://|file|\u5f53\u4f60\u6c89\u7761\u65f6.E19.\u97e9\u8bed\u4e2d\u5b57.720p.HDTV.\u521d\u5fc3\u5b57\u5e55\u7ec4.V2.mp4|605622994|97ad8074dfe1d2bcf8c15f61943a8cb3|h=lms37x5qy6aurpa3ife72mcmdrnvswkd|/',
#    u'status': u'0',
#    u'task_id': u'2135725415',
#    u'task_name': u'\u5f53\u4f60\u6c89\u7761\u65f6.E19.\u97e9\u8bed\u4e2d\u5b57.720p.HDTV.\u521d\u5fc3\u5b57\u5e55\u7ec4.V2.mp4',
#    u'timeout': u'0'},
#   {u'callback': u'',
#    u'create_time': u'1511526766',
#    u'od_type': u'3',
#    u'rate_limit': u'0',
#    u'save_path': u'/MovieCatcherFiles/\u5f53\u4f60\u6c89\u7761\u65f6.E19.\u97e9\u8bed\u4e2d\u5b57.720p.HDTV.\u521d\u5fc3\u5b57\u5e55\u7ec4.V2.mp4',
#    u'source_url': u'ed2k://|file|\u5f53\u4f60\u6c89\u7761\u65f6.E19.\u97e9\u8bed\u4e2d\u5b57.720p.HDTV.\u521d\u5fc3\u5b57\u5e55\u7ec4.V2.mp4|605622994|97ad8074dfe1d2bcf8c15f61943a8cb3|h=lms37x5qy6aurpa3ife72mcmdrnvswkd|/',
#    u'status': u'0',
#    u'task_id': u'2135641987',
#    u'task_name': u'\u5f53\u4f60\u6c89\u7761\u65f6.E19.\u97e9\u8bed\u4e2d\u5b57.720p.HDTV.\u521d\u5fc3\u5b57\u5e55\u7ec4.V2.mp4',
#    u'timeout': u'0'},
#   {u'callback': u'',
#    u'create_time': u'1511526651',
#    u'od_type': u'3',
#    u'rate_limit': u'0',
#    u'save_path': u'/MovieCatcherFiles/\u5f53\u4f60\u6c89\u7761\u65f6.E20.\u97e9\u8bed\u4e2d\u5b57.720p.HDTV.\u521d\u5fc3\u5b57\u5e55\u7ec4.V2.mp4',
#    u'source_url': u'ed2k://|file|\u5f53\u4f60\u6c89\u7761\u65f6.E20.\u97e9\u8bed\u4e2d\u5b57.720p.HDTV.\u521d\u5fc3\u5b57\u5e55\u7ec4.V2.mp4|615210363|93147e497f990c0535167d807fa7a6d3|h=bgbc66xknvhlkifenegnuuhould2p3vv|/',
#    u'status': u'0',
#    u'task_id': u'2135636843',
#    u'task_name': u'\u5f53\u4f60\u6c89\u7761\u65f6.E20.\u97e9\u8bed\u4e2d\u5b57.720p.HDTV.\u521d\u5fc3\u5b57\u5e55\u7ec4.V2.mp4',
#    u'timeout': u'0'},
#   {u'callback': u'',
#    u'create_time': u'1511526639',
#    u'od_type': u'3',
#    u'rate_limit': u'0',
#    u'save_path': u'/MovieCatcherFiles/\u5f53\u4f60\u6c89\u7761\u65f6.E21.\u97e9\u8bed\u4e2d\u5b57.720p.HDTV.\u521d\u5fc3\u5b57\u5e55\u7ec4.mp4',
#    u'source_url': u'ed2k://|file|\u5f53\u4f60\u6c89\u7761\u65f6.E21.\u97e9\u8bed\u4e2d\u5b57.720p.HDTV.\u521d\u5fc3\u5b57\u5e55\u7ec4.mp4|490606746|e6b7e57c9c477643e1527f3da0b8ce70|h=txoe3tlxnjpejmta6dkxj5iyzydv6lrp|/',
#    u'status': u'1',
#    u'task_id': u'2135636351',
#    u'task_name': u'\u5f53\u4f60\u6c89\u7761\u65f6.E21.\u97e9\u8bed\u4e2d\u5b57.720p.HDTV.\u521d\u5fc3\u5b57\u5e55\u7ec4.mp4',
#    u'timeout': u'0'},
#   {u'callback': u'',
#    u'create_time': u'1511525894',
#    u'od_type': u'3',
#    u'rate_limit': u'0',
#    u'save_path': u'/MovieCatcherFiles/\u5f53\u4f60\u6c89\u7761\u65f6.E19.\u97e9\u8bed\u4e2d\u5b57.720p.HDTV.\u521d\u5fc3\u5b57\u5e55\u7ec4.V2.mp4',
#    u'source_url': u'ed2k://|file|\u5f53\u4f60\u6c89\u7761\u65f6.E19.\u97e9\u8bed\u4e2d\u5b57.720p.HDTV.\u521d\u5fc3\u5b57\u5e55\u7ec4.V2.mp4|605622994|97ad8074dfe1d2bcf8c15f61943a8cb3|h=lms37x5qy6aurpa3ife72mcmdrnvswkd|/',
#    u'status': u'0',
#    u'task_id': u'2135603090',
#    u'task_name': u'\u5f53\u4f60\u6c89\u7761\u65f6.E19.\u97e9\u8bed\u4e2d\u5b57.720p.HDTV.\u521d\u5fc3\u5b57\u5e55\u7ec4.V2.mp4',
#    u'timeout': u'0'},
#   {u'callback': u'',
#    u'create_time': u'1511525875',
#    u'od_type': u'3',
#    u'rate_limit': u'0',
#    u'save_path': u'/MovieCatcherFiles/\u5f53\u4f60\u6c89\u7761\u65f6.E21.\u97e9\u8bed\u4e2d\u5b57.720p.HDTV.\u521d\u5fc3\u5b57\u5e55\u7ec4.mp4',
#    u'source_url': u'ed2k://|file|\u5f53\u4f60\u6c89\u7761\u65f6.E21.\u97e9\u8bed\u4e2d\u5b57.720p.HDTV.\u521d\u5fc3\u5b57\u5e55\u7ec4.mp4|490606746|e6b7e57c9c477643e1527f3da0b8ce70|h=txoe3tlxnjpejmta6dkxj5iyzydv6lrp|/',
#    u'status': u'1',
#    u'task_id': u'2135602302',
#    u'task_name': u'\u5f53\u4f60\u6c89\u7761\u65f6.E21.\u97e9\u8bed\u4e2d\u5b57.720p.HDTV.\u521d\u5fc3\u5b57\u5e55\u7ec4.mp4',
#    u'timeout': u'0'},
#   {u'callback': u'',
#    u'create_time': u'1511523944',
#    u'od_type': u'3',
#    u'rate_limit': u'0',
#    u'save_path': u'/MovieCatcherFiles/\u5f53\u4f60\u6c89\u7761\u65f6.E20.\u97e9\u8bed\u4e2d\u5b57.720p.HDTV.\u521d\u5fc3\u5b57\u5e55\u7ec4.V2.mp4',
#    u'source_url': u'ed2k://|file|\u5f53\u4f60\u6c89\u7761\u65f6.E20.\u97e9\u8bed\u4e2d\u5b57.720p.HDTV.\u521d\u5fc3\u5b57\u5e55\u7ec4.V2.mp4|615210363|93147e497f990c0535167d807fa7a6d3|h=bgbc66xknvhlkifenegnuuhould2p3vv|/',
#    u'status': u'0',
#    u'task_id': u'2135522698',
#    u'task_name': u'\u5f53\u4f60\u6c89\u7761\u65f6.E20.\u97e9\u8bed\u4e2d\u5b57.720p.HDTV.\u521d\u5fc3\u5b57\u5e55\u7ec4.V2.mp4',
#    u'timeout': u'0'},
#   {u'callback': u'',
#    u'create_time': u'1510068532',
#    u'od_type': u'3',
#    u'rate_limit': u'0',
#    u'save_path': u'/MovieCatcherFiles/\u9ed1\u955c.Black.Mirror.S03E02.\u4e2d\u82f1\u5b57\u5e55.WEB-HR.AAC.1024X576.x264.mp4',
#    u'source_url': u'ed2k://|file|%E9%BB%91%E9%95%9C.Black.Mirror.S03E02.%E4%B8%AD%E8%8B%B1%E5%AD%97%E5%B9%95.WEB-HR.AAC.1024X576.x264.mp4|566528765|908100c3f6d1d711acfbbe4c92fdc689|h=fcg2lromtic26a23fcw7bzfak7ba2gjz|/',
#    u'status': u'0',
#    u'task_id': u'2108366567',
#    u'task_name': u'\u9ed1\u955c.Black.Mirror.S03E02.\u4e2d\u82f1\u5b57\u5e55.WEB-HR.AAC.1024X576.x264.mp4',
#    u'timeout': u'0'},
#   {u'callback': u'',
#    u'create_time': u'1510060565',
#    u'od_type': u'3',
#    u'rate_limit': u'0',
#    u'save_path': u'/MovieCatcherFiles/\u9ed1\u955c.Black.Mirror.S03E01.\u4e2d\u82f1\u5b57\u5e55.WEB-HR.AAC.1024X576.x264.mp4',
#    u'source_url': u'ed2k://|file|%E9%BB%91%E9%95%9C.Black.Mirror.S03E01.%E4%B8%AD%E8%8B%B1%E5%AD%97%E5%B9%95.WEB-HR.AAC.1024X576.x264.mp4|625835952|7a9ad2e920bad093c697c6d4993f239d|h=tmqpfjyhvruvtlsuzmsfn5sfegcwhrh2|/',
#    u'status': u'0',
#    u'task_id': u'2108128960',
#    u'task_name': u'\u9ed1\u955c.Black.Mirror.S03E01.\u4e2d\u82f1\u5b57\u5e55.WEB-HR.AAC.1024X576.x264.mp4',
#    u'timeout': u'0'},
#   {u'callback': u'',
#    u'create_time': u'1510060067',
#    u'od_type': u'3',
#    u'rate_limit': u'0',
#    u'save_path': u'/MovieCatcherFiles/Black.Mirror.S03E01.PROPER.720p.WEBRip.X264-DEFLATE.mkv',
#    u'source_url': u'ed2k://|file|Black.Mirror.S03E01.PROPER.720p.WEBRip.X264-DEFLATE.mkv|1561484343|7EFE211FCD9FB995D9BCF544B4F9EE41|h=YUU6MLO43CWUPQIO3CZKTADPOTVCNEFP|/',
#    u'status': u'0',
#    u'task_id': u'2108114362',
#    u'task_name': u'Black.Mirror.S03E01.PROPER.720p.WEBRip.X264-DEFLATE.mkv',
#    u'timeout': u'0'}],
#  u'total': 106}
